# %%
from __future__ import print_function, division

import torch

import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
from torchvision import datasets, models
import matplotlib.pyplot as plt
import time
import os
import copy
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
from HelperFns import *

# %%
l1Lambda = 0
l2Lambda = 1
record_freq = 25
batch_size = 64
img_means = torch.Tensor([0.485, 0.456, 0.406])
img_stds = torch.tensor([0.229, 0.224, 0.225])
resnet = torchvision.models.resnet18(pretrained=True, progress=True).cuda()
for param in resnet.parameters():
    param.requires_grad= False

# %%
resnet.fc = nn.Linear(in_features = 512, out_features = 5, bias = True).cuda()

# %%
train_losses = []
val_losses = []
train_acc = []
val_acc = []

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(img_means, img_stds)
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(img_means, img_stds)
    ]),
}

data_dir = 'data/Linnaeus 5 256X256'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=4, pin_memory = True)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
print(out.shape)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# torch.Size([3, 1810, 1810])

# %%
def train_model(model, optimizer, num_epochs = 25):
    for epoch in range(num_epochs):
        for phase in ['train', 'test']:
            running_loss = 0.0
            running_correct = 0.0
            running_total = 0.0
            if phase == 'train':
                model.train()
            elif phase == 'test':
                model.eval()
            batches = iter(dataloaders[phase])
            for images, labels in batches:
                batch_size = len(labels)
                cudaIm = images.cuda()
                output = model(cudaIm)
                _, pred = torch.max(output, 1)
                model.zero_grad()
                one_hot = torch.zeros(batch_size,5).cuda()
                for i in range(batch_size):
                    one_hot[i][labels[i]] = 1
                loss = nn.functional.mse_loss(output, one_hot)
                l1_loss = 0
                l2_loss = 0
                for weight in resnet.fc.weight:
                    l1_loss += torch.sum(torch.abs(weight)).item() * l1Lambda #add l1 regularization term (Lasso)
                    l2_loss += torch.sum(weight*weight).item() * l2Lambda #add L2 regularization term (Ridge)
                loss += l1_loss + l2_loss
                running_total += batch_size
                running_loss += loss
                running_correct += torch.sum(pred == labels.data.cuda()).item()
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                    if running_total%record_freq == 0:
                        train_losses.append(loss/batch_size)
                        train_acc.append(running_correct/running_total)
                elif phase == 'test':
                    if running_total%record_freq == 0:
                        val_losses.append(loss/batch_size)
                        val_acc.append(running_correct/running_total)
                
                
            print("epoch: {} mode: {} avg loss: {} accuracy: {}".format(epoch, phase, 
                                                                      running_loss/running_total, 
                                                                      running_correct/running_total))

# %%
adam = optim.Adam(resnet.fc.parameters())#only train parameters of linear regression layer
train_model(resnet, adam, 10)
# Out:
# epoch: 0 mode: train avg loss: 0.025041941553354263 accuracy: 0.6623333333333333
# epoch: 0 mode: test avg loss: 0.020653365179896355 accuracy: 0.87
# epoch: 1 mode: train avg loss: 0.017634348943829536 accuracy: 0.8683333333333333
# epoch: 1 mode: test avg loss: 0.01590554416179657 accuracy: 0.9335
# epoch: 2 mode: train avg loss: 0.014231223613023758 accuracy: 0.8956666666666667
# epoch: 2 mode: test avg loss: 0.01321552973240614 accuracy: 0.945
# epoch: 3 mode: train avg loss: 0.01205970998853445 accuracy: 0.9171666666666667
# epoch: 3 mode: test avg loss: 0.011585253290832043 accuracy: 0.9495
# epoch: 4 mode: train avg loss: 0.01065203920006752 accuracy: 0.9181666666666667
# epoch: 4 mode: test avg loss: 0.010071526281535625 accuracy: 0.965
# epoch: 5 mode: train avg loss: 0.009558431804180145 accuracy: 0.9176666666666666
# epoch: 5 mode: test avg loss: 0.00910597201436758 accuracy: 0.9585
# epoch: 6 mode: train avg loss: 0.008672382682561874 accuracy: 0.9253333333333333
# ...

# %%
plt.subplots_adjust(hspace = 0.5)
plt.subplot(4, 1, 1)
plt.plot(range(len(train_losses)), train_losses, label = "train losses")
plt.legend()
plt.subplot(4, 1, 2)
plt.plot(range(len(val_losses)), val_losses, label = "validation losses")
plt.legend()
plt.subplot(4, 1, 3)
plt.plot(range(len(train_acc)), train_acc, label = "train accuracy")
plt.legend()
plt.subplot(4, 1, 4)
plt.plot(range(len(val_acc)), val_acc, label = "validation accuracy")
plt.legend()
plt.xlabel("Steps (x25)")
plt.ylim(0, 1)
plt.show()

# %%
"""
Computes an attribution vector by the integrated gradient method described in Axiomatic Attribution for Neural Networks for a single image.
Assumes input is a single color image with 3 dimensions (channel, width, height)
Returns an attribution tensor of same dimensions as input image
"""
def attribute(model, image, base, steps = 100): 
    for param in model.parameters():
        param.requires_grad = True
    model.eval()
    #diff = image - base
    baseShape = base.shape
    imageShape = image.shape
    baseBatch = base.view(1, baseShape[0], baseShape[1], baseShape[2])
    imageBatch = image.view(1, imageShape[0], imageShape[1], imageShape[2])
    gradSum = torch.zeros([model.fc.out_features, imageShape[0], imageShape[1], imageShape[2]], device=image.device)
    diff = imageBatch - baseBatch
    imshow(image.detach().cpu())
    for i in range(steps):
        new = baseBatch + diff * i / steps
        new.requires_grad = True
        newShape = new.shape
        out = model(new)
        for j in range(5):
            model.zero_grad()
            if (new.grad != None):
                new.grad.zero_()
            out[0][j].backward(retain_graph = True)
            gradTensor = new.grad
            gradSum[j] = gradTensor + gradSum[j]
        
    gradSum /= steps
    result = gradSum * diff
    baseScore = model(baseBatch)
    inScore = model(imageBatch)
    diffSum = torch.sum(inScore - baseScore)
    resultSum = torch.sum(result)
    print("gradients vs score diff: ", abs((resultSum - diffSum)/diffSum).item() * 100,  "%")
    print("gradientSum: ", torch.sum(resultSum), "diffSum: ", diffSum)
    return result, torch.argmax(out[0])

# %%
batches = iter(dataloaders['test'])
images, labels = next(batches)
image = images[0]
label = labels[0]
base = black_like(image, img_means, img_stds)#blurred_like(image, img_means, img_stds)
att, guess = attribute(resnet, image.cuda(), base.cuda(), 300)
# Out:
# gradients vs score diff:  11.2727552652359 %
# gradientSum:  tensor(0.2961, device='cuda:0') diffSum:  tensor(0.3338, device='cuda:0', grad_fn=<SumBackward0>)

# %%
att_sum = att.sum(axis = 1) #sum along color axis
for i in range(att_sum.shape[0]):
    scale(att_sum[i])
#flat = torch.flatten(att_sum)
#sorted, _ = torch.sort(flat)
#plt.plot(sorted.cpu())
#plt.show()
imshow(image, "original")
attShape = att_sum.shape
print("classification: ", guess.item(), " label: ", label.item())
#att_sum = torch.abs(att_sum)
att_imshow(image, att_sum[label].detach().cpu(), "scaled")
heatmap_imshow(att_sum[label].detach().cpu(), "heatmap")
# Out:
# classification:  2  label:  2

# %%
out2 = torchvision.utils.make_grid(image4)
outputs = []
for sub in att:
    outputs.append(torchvision.utils.make_grid(sub))
    imshow(out2)
    show_att(outputs[-1].cpu().detach(), out2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f1879e453251> in <module>
# ----> 1 out2 = torchvision.utils.make_grid(image4)
#       2 outputs = []
#       3 for sub in att:
#       4     outputs.append(torchvision.utils.make_grid(sub))
#       5     imshow(out2)
#
# NameError: name 'image4' is not defined

# %%
def get_num_correct(preds, labels):
    return preds.argmax(dim = 1).eq(labels).sum().item()

# %%
batches = iter(test_loader)
num_correct = 0
num_test = 0
total_loss = 0
for image_batch, label_batch in batches:
    pred = network(image_batch)
    one_hot = torch.zeros(len(label_batch),2)
    for i in range(batch_size):
        one_hot[i][labels[i]] = 1
    loss = nn.functional.mse_loss(output, one_hot.cuda())
    l1_loss = 0
    l2_loss = 0
    for weight in resnet.fc.weight:
        l1_loss += torch.sum(torch.abs(weight)) * l1Lambda #add l1 regularization term (Lasso)
        l2_loss += torch.sum(weight*weight) * l2Lambda #add L2 regularization term (Ridge)
    loss += l1_loss + l2_loss
    num_correct += get_num_correct(pred, label_batch)
    num_test += 100
    total_loss += loss
print("accuracy on test dataset: {}, average loss: {}".format(num_correct/num_test, total_loss/num_test) )
